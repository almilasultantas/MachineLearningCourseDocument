# %% [markdown]
# Makine öğrenmesi modellerine giriş

# %% [markdown]
# Tahmin(prediction) forecasting(öngörü) farkı
#
# prediction>forecasting forecasting ileride olacak olan tahmin yaparken prediction ise geçmiş gelecek arada ki bi değerin tahminini yapabiliyor

# %%
# prediction \ Tahmin
# Simple Linear Regression (Basit Doğrusal regresyon)
# örn borsa tahmini

import pandas as pd # veriler için 
import numpy as np # büyük sayılar ve hesaplamalar için kullandığımız kütüphane 
import matplotlib.pyplot as plt # çizimler için

veriler = pd.read_csv("satislar.csv")
#print(veriler)

aylar = veriler[["Aylar"]]

satislar = veriler[["Satislar"]]

satislar2 = veriler.iloc[:,:1].values
'''satışların aya bağlı olduğunu düşünüyoruz o yüzden 
satışlar bağımlı değişken aylar bağımsız değişken
'''
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(aylar,satislar,test_size = 0.33, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#X_train = sc.fit_transform(x_train)
#X_test = sc.fit_transform(x_test)

#Y_train = sc.fit_transform(y_train)
#Y_test = sc.fit_transform(y_test)

# %%
#print (X_train)
#print (X_test)
#print(y_train)
#print(y_test)'''

# %%
#model inşası
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)#modelin oluşturulması sağlanıyor

tahmin = lr.predict(x_test)
#print(tahmin)

# %%
#verileri görselleştirme kısmı
#print(plt.plot(x_train,y_train))
x_train = x_train.sort_index() #verileri sıralamamızı sağlıyor
y_train = y_train.sort_index()
plt.title("Aylara Göre Satış")
plt.xlabel("Aylar")
plt.ylabel("Satışlar")
plt.plot(x_train,y_train)
plt.plot(x_test,lr.predict(x_test))
